# %% [markdown]
# # 02 Feature Engineering
#
# 이 노트북은 블로그 설명용입니다. 실제 실행 기준은 `src/`의 CLI 스크립트입니다.

# %%
# 예시
# !python ../src/data_pipeline.py --ticker 005930 --start 2018-01-01 --end 2025-12-31 --use-sample
